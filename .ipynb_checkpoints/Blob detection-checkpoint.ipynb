# %%
import cv2
from matplotlib import pyplot as plt
from matplotlib import image as img
import numpy as np
import os
import imutils
from PIL import Image

# %%
im = cv2.imread("/projects/qg35/jlgao2/FYP-Sandbox/data/h5/roc/L15/8589200_5535200.tif", 0)

inv = cv2.bitwise_not(im)
plt.imshow(im)

# %%
gt = cv2.imread("/projects/qg35/jlgao2/FYP-Sandbox/data/h5/masks2/8589200_5535200_mask.tif", 0)
plt.imshow(gt)

# %%
pcontours = cv2.findContours(im, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
pcontours = imutils.grab_contours(pcontours)

# %%
len(pcontours)
# Out:
# 326

# %%
gtcontours = cv2.findContours(gt, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
gtcontours = imutils.grab_contours(gtcontours)
len(gtcontours)
# Out:
# 198

# %%
image = Image.open("/projects/qg35/jlgao2/FYP-Sandbox/data/h5/roc/06/8589200_5535200.tif")

# %%
print(image.format)
print(image.size)
print(image.mode)
# Out:
# TIFF
# (400, 400)
# LA

# %%
gtcontours
# Out:
# [array([[[397, 389]],
#
#         [[396, 390]],
#
#         [[394, 390]],
#
#         [[393, 391]],
#
#         [[391, 391]],
#
#         [[390, 392]],
#
#         [[388, 392]],
#
#         [[387, 393]],
#
#         [[385, 393]],
#
#         [[384, 394]],
#
#         [[382, 394]],
#
#         [[381, 395]],
#
#         [[379, 395]],
#
#         [[378, 396]],
#
#         [[377, 396]],
#
#         [[376, 397]],
#
#         [[374, 397]],
#
#         [[373, 398]],
#
#         [[371, 398]],
#
#         [[370, 399]],
#
#         [[368, 399]],
#
#         [[383, 399]],
#
#         [[385, 397]],
#
#         [[386, 397]],
#
#         [[388, 399]],
#
#         [[390, 399]],
#
#         [[390, 397]],
#
#         [[392, 395]],
#
#         [[394, 395]],
#
#         [[395, 394]],
#
#         [[397, 396]],
#
#         [[397, 399]],
#
#         [[399, 399]],
#
#         [[399, 389]]], dtype=int32),
#  array([[[ 37, 375]],
#
#         [[ 34, 378]],
#
#         [[ 33, 378]],
#
#         [[ 34, 379]],
# ...

# %%
## Alexis' code

def eval_contour_in_contour(images, preds, masks, masks2, names):
    import cv2, imutils

    new_images, accuracy, total_mask, total_pred, total_extra, total_inmask, score_inmask, score_extra  = [], [], [], [], [],[], [], []
    for x in range(len(preds)):
        tot_inmask, tot_extra=0,0
        sc_inmask = 100

        found_cnt=set()
        im=preds[x]
        im=np.uint8(im*255)
        pcontours = cv2.findContours(im, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        pcontours = imutils.grab_contours(pcontours)

        im=masks[x]
        im=np.uint8(im*255)
        mcontours = cv2.findContours(im, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        mcontours = imutils.grab_contours(mcontours)

        im=masks2[x]
        im=np.uint8(im*255)
        ccontours = cv2.findContours(im, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        ccontours = imutils.grab_contours(ccontours)

        for pred_cnt in pcontours:
            M = cv2.moments(pred_cnt)
            cX = 0 if M["m00"] == 0 else int(M["m10"] / M["m00"])
            cY = 0 if M["m00"] == 0 else int(M["m01"] / M["m00"])

            # img = cv2.circle(im, (cX, cY), 3, (255, 255, 255), -1)

            belongs = False
            for mask_cnt in ccontours:
                if cv2.pointPolygonTest(mask_cnt, (cX, cY), False) > 0:
                    belongs = True
                    found_cnt.add(str(mask_cnt))
                    break
            if belongs:
                tot_inmask += 1
            else:
                tot_extra += 1

        # percantage of how many predictions correctly fell into the masks contours
        if len(mcontours)>0:
            sc_inmask=100*tot_inmask/len(mcontours)

        sc_extra=0 if len(pcontours)==0 else 100*tot_extra/len(pcontours)


        total_mask.append(len(mcontours))
        total_pred.append(len(pcontours))
        total_inmask.append(tot_inmask)
        total_extra.append(tot_extra)
        score_inmask.append(sc_inmask)
        score_extra.append(sc_extra)



    accuracies = pd.DataFrame(zip(total_mask,total_pred,total_inmask,total_extra,score_inmask,score_extra),
                              columns=['total_mask','total_pred','total_inmask','total_extra','score_inmask','score_extra'])
    return accuracies,new_images
