# %% [markdown]
# ## Image segmentation with fastai

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *
import os
import torchvision.transforms as tfms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
path = os.getcwd()
img_path = path+'/data/h5'
path_img = img_path+'/img_wmasks'
path_lbl = path+'/data/h5/masks2/'
path_infer = img_path+'/s2-hr/'
path_infer_400 = img_path+'/s2-hr-400/'
path_infer_mask = img_path+'/s2-hr-mask/'
il = ImageList.from_folder(path_infer_400)
gt_il = ImageList.from_folder(path_img)

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_infer_400)
img_f = fnames[0]
lbl_names = get_image_files(path_lbl)
get_y_fn = lambda x: path_lbl+f'/{x.stem}_mask.tif'
mask = open_mask(get_y_fn(img_f))

src_size = np.array(mask.shape[1:])
codes = array(['Background' , 'Building'])
size = src_size//2


free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=16
else:           bs=8
print(f"using bs={bs}, have {free}MB of GPU RAM free")

src = (SegmentationItemList.from_folder(path_infer_400)
       .split_by_rand_pct()
       .label_from_func(get_y_fn, classes=codes))

data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-4856e2e69b0d> in <module>
#       3 lbl_names = get_image_files(path_lbl)
#       4 get_y_fn = lambda x: path_lbl+f'/{x.stem}_mask.tif'
# ----> 5 mask = open_mask(get_y_fn(img_f))
#       6
#       7 src_size = np.array(mask.shape[1:])
#
# /projects/qg35/jlgao2/venvs/lib/python3.7/site-packages/fastai/vision/image.py in open_mask(fn, div, convert_mode, after_open)
#     404 def open_mask(fn:PathOrStr, div=False, convert_mode='L', after_open:Callable=None)->ImageSegment:
#     405     "Return `ImageSegment` object create from mask in file `fn`. If `div`, divides pixel values by 255."
# --> 406     return open_image(fn, div=div, convert_mode=convert_mode, cls=ImageSegment, after_open=after_open)
#     407
#     408 def open_mask_rle(mask_rle:str, shape:Tuple[int, int])->ImageSegment:
#
# /projects/qg35/jlgao2/venvs/lib/python3.7/site-packages/fastai/vision/image.py in open_image(fn, div, convert_mode, cls, after_open)
#     396     with warnings.catch_warnings():
#     397         warnings.simplefilter("ignore", UserWarning) # EXIF warning from TiffPlugin
# --> 398         x = PIL.Image.open(fn).convert(convert_mode)
#     399     if after_open: x = after_open(x)
#     400     x = pil2tensor(x,np.float32)
#
# /projects/qg35/jlgao2/venvs/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/projects/qg35/jlgao2/FYP-Sandbox/data/h5/masks2//9148000_5818800_result_mask.tif'

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Background']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

metrics=acc_camvid
wd=1e-2

learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %% [markdown]
# ## Datasets

# %%
data.valid_dl = data.valid_dl.new(shuffle=True)

# %%
lr=3e-3

# %%
lrs = slice(lr/400,lr/4)

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=3
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a5beb296887e> in <module>
# ----> 1 learn.destroy()
#       2
#       3 size = src_size
#       4
#       5 free = gpu_mem_get_free_no_cache()
#
# NameError: name 'learn' is not defined

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='70' class='' max='1103' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.35% [70/1103 00:44<10:55 0.2727]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.192988</td>
#       <td>0.194877</td>
#       <td>0.563373</td>
#       <td>11:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.206289</td>
#       <td>0.189780</td>
#       <td>0.586875</td>
#       <td>11:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.197930</td>
#       <td>0.188354</td>
#       <td>0.594897</td>
#       <td>11:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.183384</td>
#       <td>0.187282</td>
#       <td>0.636533</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.188211</td>
#       <td>0.185410</td>
#       <td>0.616907</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.196201</td>
#       <td>0.183721</td>
#       <td>0.607978</td>
#       <td>11:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.195956</td>
#       <td>0.181219</td>
#       <td>0.601281</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.180226</td>
#       <td>0.181549</td>
#       <td>0.616118</td>
#       <td>11:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.195746</td>
#       <td>0.179340</td>
#       <td>0.641098</td>
#       <td>11:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.180412</td>
#       <td>0.176606</td>
#       <td>0.623988</td>
#       <td>11:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.178157</td>
#       <td>0.177290</td>
#       <td>0.627877</td>
#       <td>23:40</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.194858</td>
#       <td>0.184552</td>
#       <td>0.541604</td>
#       <td>23:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.174221</td>
#       <td>0.235006</td>
#       <td>0.601460</td>
#       <td>23:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.208536</td>
#       <td>0.201562</td>
#       <td>0.565716</td>
#       <td>23:37</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.190903</td>
#       <td>0.184813</td>
#       <td>0.603753</td>
#       <td>23:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.180338</td>
#       <td>0.194739</td>
#       <td>0.575114</td>
#       <td>23:36</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.194246</td>
#       <td>0.205351</td>
#       <td>0.607111</td>
#       <td>23:37</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.173586</td>
#       <td>0.268123</td>
#       <td>0.581080</td>
#       <td>23:37</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.186383</td>
#       <td>0.388126</td>
#       <td>0.591671</td>
#       <td>23:37</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.195230</td>
#       <td>0.969050</td>
#       <td>0.591985</td>
#       <td>23:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cc9674decc22> in <module>
# ----> 1 learn.load('stage-2-big');
#
# NameError: name 'learn' is not defined

# %%
learn.show_results(rows=3, figsize=(10,10))

# %%
learn.export()

# %%
learn = load_learner(path_img)

# %% [markdown]
# ## Inference

# %%
path_infer = img_path+'/s2-hr/'
path_infer_400 = img_path+'/s2-hr-400/'
path_infer_mask = img_path+'/s2-hr-mask/'
il = ImageList.from_folder(path_infer_400)
gt_il = ImageList.from_folder(path_img)

# %%
#runonce
onlypngs = []
onlypngs = [f for f in os.listdir(path_infer) if os.path.isfile(os.path.join(path_infer, f))]


for line in onlypngs:
    gt = Image.open(path_infer+line)
    fn = line.replace("_result", "")
    gt = gt.resize((400, 400))
    gt.save(path_infer_400+fn)

# %%
img = il[1]

# %%
onlypngs
# Out:
# ['9148000_5818800_result.png',
#  '8591200_5544800_result.png',
#  '9056400_5682000_result.png',
#  '9294400_5559600_result.png',
#  '8338400_5494000_result.png',
#  '8289200_5493600_result.png',
#  '9278800_5861600_result.png',
#  '9280000_5872000_result.png',
#  '8817600_5992400_result.png',
#  '9368000_5532800_result.png',
#  '9153200_5818800_result.png',
#  '8337600_5494800_result.png',
#  '9284000_5865200_result.png',
#  '8332800_5494000_result.png',
#  '9153600_5818000_result.png',
#  '9270800_5675600_result.png',
#  '9072400_5682000_result.png',
#  '8589200_5539200_result.png',
#  '8596800_5537600_result.png',
#  '9152800_5823200_result.png',
#  '8334000_5492400_result.png',
#  '9068400_5681200_result.png',
#  '9280800_5673600_result.png',
#  '8339200_5491600_result.png',
#  '9605200_6073200_result.png',
#  '8494000_5766800_result.png',
#  '9277200_5863200_result.png',
#  '9370000_5517200_result.png',
#  '8819200_5992800_result.png',
#  '9060400_5682000_result.png',
#  '8490000_5774000_result.png',
#  '9063200_5688800_result.png',
#  '8491600_5772800_result.png',
#  '8367600_5548000_result.png',
#  '8291600_5496000_result.png',
#  '9150400_5822400_result.png',
#  '9364400_5514800_result.png',
#  '8588000_5628400_result.png',
#  '9145200_5818800_result.png',
#  '9142800_5820000_result.png',
#  '9144800_5822400_result.png',
#  '9151600_5810800_result.png',
#  '8338400_5492000_result.png',
#  '8333600_5492000_result.png',
#  '8825600_5995600_result.png',
#  '9365200_5519600_result.png',
#  '8337200_5493200_result.png',
#  '9066400_5678000_result.png',
#  '8598000_5536800_result.png',
#  '9270000_5669600_result.png',
#  '9054400_5684000_result.png',
#  '8495600_5773200_result.png',
#  '8290000_5498000_result.png',
#  '8290000_5496400_result.png',
#  '9157200_5820000_result.png',
#  '9296400_5556400_result.png',
#  '9061600_5689200_result.png',
#  '9146800_5818800_result.png',
#  '8588800_5541200_result.png',
#  '8589200_5626800_result.png',
#  '9066000_5680800_result.png',
#  '8495200_5767200_result.png',
#  '9374800_5528400_result.png',
#  '9602000_6068400_result.png',
#  '8494000_5773200_result.png',
#  '8491200_5773600_result.png',
#  '8820000_5988000_result.png',
#  '9366000_5529200_result.png',
#  '9279600_5865600_result.png',
#  '8865200_5686400_result.png',
#  '9066800_5677600_result.png',
#  '9055600_5687600_result.png',
#  '9064000_5681600_result.png',
#  '8508400_5773200_result.png',
#  '9152000_5815600_result.png',
#  '9066000_5688800_result.png',
#  '8498400_5772400_result.png',
#  '8508800_5765200_result.png',
#  '9152400_5816400_result.png',
#  '9300800_5556000_result.png',
#  '9150000_5819200_result.png',
#  '8490400_5773600_result.png',
#  '8493200_5769200_result.png',
#  '9066000_5682800_result.png',
#  '9376800_5526800_result.png',
#  '8493200_5777200_result.png',
#  '9146400_5819200_result.png',
#  '8371200_5550800_result.png',
#  '8496800_5764400_result.png',
#  '9367600_5532400_result.png',
#  '8827200_5994800_result.png',
#  '9054400_5682000_result.png',
#  '8366000_5547600_result.png',
#  '9153600_5810800_result.png',
#  '9274400_5861600_result.png',
#  '8370800_5549600_result.png',
#  '9272000_5864000_result.png',
#  '8333600_5492400_result.png',
#  '9065200_5680000_result.png',
#  '9298000_5564000_result.png',
#  '8814800_5995600_result.png',
#  '9364400_5522400_result.png',
#  '8500000_5770800_result.png',
#  '8368800_5548800_result.png',
#  '8495600_5774800_result.png',
#  '9071200_5682800_result.png',
#  '8866000_5683600_result.png',
#  '8592000_5528000_result.png',
#  '9058400_5681200_result.png',
#  '9295200_5560800_result.png',
#  '9375600_5526400_result.png',
#  '8505200_5764400_result.png',
#  '9302800_5562000_result.png',
#  '9058800_5690800_result.png',
#  '8830400_5992400_result.png',
#  '8591200_5537200_result.png',
#  '9299600_5562000_result.png',
#  '9280400_5869200_result.png',
#  '8495600_5765600_result.png',
#  '8292400_5499200_result.png',
#  '9366400_5522400_result.png',
#  '9272400_5669200_result.png',
#  '9602400_6066400_result.png',
#  '8336800_5495600_result.png',
#  '9154800_5814400_result.png',
#  '9145200_5820000_result.png',
#  '8825200_5996800_result.png',
#  '8492000_5775200_result.png',
#  '9065200_5688000_result.png',
#  '8496000_5768000_result.png',
#  '9606000_6070400_result.png',
#  '8493200_5767600_result.png',
#  '9061600_5682800_result.png',
#  '8334800_5492400_result.png',
#  '9292800_5559200_result.png',
#  '9273200_5673600_result.png',
#  '9067600_5688400_result.png',
#  '9291200_5555600_result.png',
#  '8291200_5498000_result.png',
#  '8491600_5776800_result.png',
#  '8286800_5496800_result.png',
#  '9273200_5872400_result.png',
#  '9062000_5683600_result.png',
#  '9366800_5515600_result.png',
#  '8366400_5548000_result.png',
#  '9296400_5558800_result.png',
#  '8494800_5775600_result.png',
#  '9152000_5822400_result.png',
#  '9065200_5678400_result.png',
#  '9064800_5679600_result.png',
#  '8491200_5772400_result.png',
#  '8286400_5496400_result.png',
#  '9069200_5682400_result.png',
#  '8488800_5770800_result.png',
#  '8290800_5496800_result.png',
#  '9605200_6069600_result.png',
#  '9060800_5687600_result.png',
#  '8582400_5539200_result.png',
#  '8497200_5765200_result.png',
#  '8492400_5768000_result.png',
#  '9154800_5811200_result.png',
#  '8337600_5494000_result.png',
#  '9299200_5561200_result.png',
#  '9371600_5525600_result.png',
#  '9284400_5871600_result.png',
#  '9058000_5688400_result.png',
#  '9061200_5685600_result.png',
#  '9599200_6072000_result.png',
#  '9298000_5563600_result.png',
#  '9302800_5558400_result.png',
#  '8367200_5548800_result.png',
#  '9295200_5558800_result.png',
#  '9278400_5862000_result.png',
#  '8953600_5841600_result.png',
#  '9366400_5525600_result.png',
#  '9063200_5685600_result.png',
#  '8492400_5772800_result.png',
#  '9285600_5867200_result.png',
#  '9060000_5684800_result.png',
#  '9153600_5822400_result.png',
#  '9057200_5684000_result.png',
#  '8335200_5490000_result.png',
#  '9065600_5682400_result.png',
#  '9273600_5676400_result.png',
#  '9275200_5870000_result.png',
#  '8508400_5764400_result.png',
#  '8585600_5541600_result.png',
#  '9273600_5866400_result.png',
#  '8504000_5770000_result.png',
#  '9052000_5682400_result.png',
#  '9298400_5555600_result.png',
#  '9061200_5680000_result.png',
#  '9063200_5688400_result.png',
#  '8492400_5768400_result.png',
#  '8370800_5551200_result.png',
#  '9060800_5691200_result.png',
#  '9270000_5667600_result.png',
#  '9280000_5869200_result.png',
#  '9060000_5687600_result.png',
#  '8590000_5540800_result.png',
#  '9064400_5680400_result.png',
#  '9064400_5686400_result.png',
#  '9374000_5530800_result.png',
#  '9154000_5819600_result.png',
#  '9273600_5672800_result.png',
#  '9376800_5522400_result.png',
#  '8495200_5776000_result.png',
#  '9154400_5814800_result.png',
#  '8489600_5773200_result.png',
#  '9064400_5678400_result.png',
#  '9157600_5816000_result.png',
#  '9604800_6068800_result.png',
#  '8494000_5771200_result.png',
#  '9052000_5682000_result.png',
#  '9154000_5815200_result.png',
#  '8865600_5686400_result.png',
#  '8370400_5551200_result.png',
#  '9060000_5686400_result.png',
#  '9274800_5668400_result.png',
#  '8504800_5768000_result.png',
#  '9299600_5562400_result.png',
#  '9366400_5528000_result.png',
#  '9292000_5563200_result.png',
#  '9062800_5680800_result.png',
#  '8863600_5687600_result.png',
#  '9061200_5681200_result.png',
#  '9272000_5874800_result.png',
#  '8817200_5992000_result.png',
#  '8508400_5762400_result.png',
#  '9149200_5812800_result.png',
#  '8489600_5771200_result.png',
#  '9601600_6071200_result.png',
#  '9154400_5811200_result.png',
#  '8493200_5768400_result.png',
#  '9368400_5530000_result.png',
#  '9062400_5688000_result.png',
#  '8492800_5775200_result.png',
#  '9061600_5687600_result.png',
#  '9065200_5677200_result.png',
#  '8505200_5771600_result.png',
#  '9061200_5684000_result.png',
#  '9068400_5685600_result.png',
#  '8494000_5772800_result.png',
#  '9062000_5688400_result.png',
#  '9064800_5678400_result.png',
#  '8590800_5534000_result.png',
#  '9063600_5682800_result.png',
#  '8814000_5994000_result.png',
#  '9374800_5526400_result.png',
#  '9372000_5528800_result.png',
#  '8334400_5494000_result.png',
#  '8288800_5493600_result.png',
#  '9064800_5682800_result.png',
#  '8290400_5496000_result.png',
#  '8338000_5492400_result.png',
#  '9367200_5528400_result.png',
#  '8493600_5775600_result.png',
#  '9367600_5515600_result.png',
#  '8288400_5494800_result.png',
#  '9065600_5679200_result.png',
#  '9364000_5524400_result.png',
#  '8286800_5496400_result.png',
#  '9600400_6073600_result.png',
#  '8337200_5492400_result.png',
#  '9364400_5522000_result.png',
#  '9143600_5820400_result.png',
#  '9280000_5861200_result.png',
#  '8291600_5499600_result.png',
#  '8334800_5494800_result.png',
#  '8827600_5992400_result.png',
#  '9272800_5865200_result.png',
#  '8369600_5549200_result.png',
#  '9150400_5820000_result.png',
#  '8289600_5498400_result.png',
#  '9280000_5676400_result.png',
#  '9057200_5688800_result.png',
#  '8590800_5628400_result.png',
#  '9068000_5687600_result.png',
#  '9062000_5680000_result.png',
#  '8592000_5627600_result.png',
#  '9371200_5533600_result.png',
#  '8590000_5533200_result.png',
#  '8502000_5766800_result.png',
#  '9069200_5685600_result.png',
#  '9158000_5816400_result.png',
#  '9145600_5821600_result.png',
#  '9370400_5525200_result.png',
#  '9366800_5527200_result.png',
#  '9065200_5681600_result.png',
#  '8592800_5538400_result.png',
#  '8286800_5497200_result.png',
#  '8496400_5777600_result.png',
#  '9276400_5672800_result.png',
#  '9606800_6072800_result.png',
#  '8334400_5496400_result.png',
#  '9609200_6074400_result.png',
#  '9283200_5865600_result.png',
#  '9271200_5863200_result.png',
#  '8366400_5549200_result.png',
#  '8492000_5771200_result.png',
#  '9273600_5666400_result.png',
#  '8368000_5548400_result.png',
#  '9144800_5819600_result.png',
#  '8582800_5540400_result.png',
#  '9064400_5681600_result.png',
#  '8494800_5768400_result.png',
#  '8494800_5773200_result.png',
#  '9157200_5818400_result.png',
#  '9272800_5672000_result.png',
#  '8495600_5767200_result.png',
#  '9064800_5682000_result.png',
#  '9154800_5815200_result.png',
#  '8366000_5549600_result.png',
#  '9295600_5561200_result.png',
#  '8590400_5535200_result.png',
#  '9159600_5821600_result.png',
#  '8828400_5994800_result.png',
#  '8490400_5774000_result.png',
#  '8334800_5493600_result.png',
#  '9274000_5669200_result.png',
#  '8494400_5768800_result.png',
#  '8820800_5992800_result.png',
#  '8822800_5995600_result.png',
#  '8369600_5549600_result.png',
#  '8370000_5551200_result.png',
#  '8335200_5496000_result.png',
#  '9299200_5554400_result.png',
#  '8493600_5774800_result.png',
#  '9060400_5681200_result.png',
#  '8368000_5549200_result.png',
#  '9061200_5680400_result.png',
#  '8495200_5774800_result.png',
#  '9284000_5868000_result.png',
#  '8496400_5765200_result.png',
#  '8489200_5772000_result.png',
#  '9060400_5691600_result.png',
#  '9148000_5817200_result.png',
#  '9061200_5690800_result.png',
#  '9153200_5812400_result.png',
#  '9062400_5682000_result.png',
#  '8494000_5769200_result.png',
#  '8494400_5776400_result.png',
#  '9062400_5678400_result.png',
#  '9056000_5686400_result.png',
#  '9064400_5682000_result.png',
#  '9150400_5816800_result.png',
#  '9068000_5678400_result.png',
#  '9062800_5687600_result.png',
#  '9157200_5816800_result.png',
#  '9062800_5681600_result.png',
#  '8370400_5548400_result.png',
#  '8587200_5541200_result.png',
#  '9149600_5820000_result.png',
#  '9148000_5818400_result.png',
#  '8288400_5498400_result.png',
#  '8824400_5992000_result.png',
#  '9364400_5525200_result.png',
#  '9373200_5528000_result.png',
#  '9375200_5523200_result.png',
#  '9363600_5529200_result.png',
#  '9065600_5688800_result.png',
#  '9378800_5528400_result.png',
#  '8597200_5533600_result.png',
#  '8813600_5992800_result.png',
#  '9063600_5688400_result.png',
#  '9063600_5684000_result.png',
#  '8493600_5774000_result.png',
#  '9298800_5553600_result.png',
#  '8506400_5765200_result.png',
#  '8494000_5768800_result.png',
#  '9068400_5678800_result.png',
#  '8289200_5498000_result.png',
#  '8494000_5775600_result.png',
#  '8333600_5491600_result.png',
#  '8591600_5533200_result.png',
#  '9158400_5814800_result.png',
#  '8812000_5990000_result.png',
#  '9054800_5682000_result.png',
#  '9293600_5557200_result.png',
#  '9064400_5683600_result.png',
#  '8503600_5771600_result.png',
#  '9275600_5674800_result.png',
#  '9154400_5816800_result.png',
#  '8492400_5770000_result.png',
#  '9604000_6076000_result.png',
#  '9063600_5688000_result.png',
#  '9152800_5816800_result.png',
#  '8491200_5776400_result.png',
#  '8334400_5490400_result.png',
#  '8493200_5772400_result.png',
#  '8863600_5686400_result.png',
#  '9275200_5867600_result.png',
#  '9057200_5691200_result.png',
#  '8336400_5490000_result.png',
#  '8493200_5768800_result.png',
#  '8863200_5687600_result.png',
#  '8506000_5762800_result.png',
#  '9160400_5821600_result.png',
#  '8827200_5995600_result.png',
#  '9068000_5679200_result.png',
#  '8493600_5776000_result.png',
#  '9061200_5679200_result.png',
#  '8338400_5491600_result.png',
#  '8812000_5991200_result.png',
#  '9378800_5523600_result.png',
#  '9157600_5818000_result.png',
#  '9064800_5688400_result.png',
#  '9374800_5524000_result.png',
#  '9058400_5692000_result.png',
#  '9153600_5819600_result.png',
#  '9297600_5563600_result.png',
#  '9062800_5686400_result.png',
#  '9265600_5670000_result.png',
#  '9067600_5684800_result.png',
#  '8337600_5492400_result.png',
#  '9064400_5683200_result.png',
#  '9154000_5811200_result.png',
#  '8496400_5769200_result.png',
#  '9063600_5689600_result.png',
#  '9375600_5526000_result.png',
#  '9296800_5564800_result.png',
#  '9062800_5678800_result.png',
#  '8367600_5548400_result.png',
#  '8492800_5771200_result.png',
#  '8490400_5770000_result.png',
#  '8334000_5491600_result.png',
#  '8490800_5774000_result.png',
#  '8491200_5772000_result.png',
#  '9064800_5686400_result.png',
#  '8589600_5540400_result.png',
#  '9059200_5689600_result.png',
#  '9298000_5561200_result.png',
#  '9060000_5690800_result.png',
#  '9276800_5870400_result.png',
#  '8493600_5768400_result.png',
#  '8288800_5498800_result.png',
#  '8289200_5497600_result.png',
#  '9281200_5871600_result.png',
#  '9154800_5812000_result.png',
#  '9154000_5811600_result.png',
#  '9145200_5819200_result.png',
#  '8826000_5991200_result.png',
#  '8821600_5990800_result.png',
#  '8338800_5492800_result.png',
#  '9280000_5861600_result.png',
#  '8492400_5774800_result.png',
#  '9301200_5561600_result.png',
#  '9275600_5859600_result.png',
#  '8489200_5774400_result.png',
#  '9060800_5680000_result.png',
#  '8492000_5767600_result.png',
#  '8336400_5492000_result.png',
#  '8290000_5497200_result.png',
#  '9272800_5669200_result.png',
#  '8490400_5771600_result.png',
#  '9064800_5680000_result.png',
#  '8598800_5535600_result.png',
#  '8336000_5492800_result.png',
#  '9064800_5681200_result.png',
#  '8499200_5768400_result.png',
#  '9065200_5678800_result.png',
#  '8288400_5496400_result.png',
#  '8862400_5687600_result.png',
#  '8334400_5491600_result.png',
#  '8493200_5776800_result.png',
#  '8591200_5632800_result.png',
#  '9372400_5522800_result.png',
#  '9370000_5517600_result.png',
#  '8494000_5772000_result.png',
#  '9367200_5524800_result.png',
#  '9369600_5518000_result.png',
#  '9146400_5814800_result.png',
#  '8491200_5770000_result.png',
#  '9070400_5686400_result.png',
#  '9159600_5820000_result.png',
#  '9376400_5529200_result.png',
#  '9364800_5524400_result.png',
#  '9064000_5680400_result.png',
#  '8594800_5529600_result.png',
#  '9065600_5684800_result.png',
#  '9298000_5559600_result.png',
#  '8495200_5768400_result.png',
#  '8592800_5626800_result.png',
#  '9374400_5530400_result.png',
#  '9060800_5680800_result.png',
#  '9061600_5679200_result.png',
#  '8490400_5774800_result.png',
#  '8588000_5537200_result.png',
#  '8290800_5498400_result.png',
#  '9273600_5672400_result.png',
#  '8494800_5775200_result.png',
#  '8508000_5767200_result.png',
#  '8825600_5996000_result.png',
#  '8495200_5779200_result.png',
#  '8499600_5772000_result.png',
#  '9063600_5687600_result.png',
#  '9265600_5672000_result.png',
#  '9063600_5678400_result.png',
#  '8595600_5630800_result.png',
#  '9368000_5516000_result.png',
#  '8499200_5764400_result.png',
#  '8491600_5770000_result.png',
#  '8491200_5771600_result.png',
#  '9281200_5868400_result.png',
#  '9060800_5682000_result.png',
#  '9064000_5678000_result.png',
#  '8583200_5541600_result.png',
#  '9151600_5812800_result.png',
#  '8590800_5531600_result.png',
#  '8495200_5773200_result.png',
#  '8494800_5766800_result.png',
#  '9155200_5816400_result.png',
#  '8495600_5767600_result.png',
#  '9065600_5680400_result.png',
#  '9267200_5672800_result.png',
#  '9368400_5521600_result.png',
#  '9060400_5684800_result.png',
#  '9152000_5810000_result.png',
#  '9063200_5684000_result.png',
#  '8490400_5768800_result.png',
#  '9066400_5682400_result.png',
#  '9062800_5689600_result.png',
#  '8494000_5766000_result.png',
#  '8494800_5773600_result.png',
#  '9601600_6069200_result.png',
#  '8291600_5498800_result.png',
#  '8818000_5992000_result.png',
#  '9057600_5690400_result.png',
#  '9276000_5865600_result.png',
#  '8592000_5534000_result.png',
#  '8586800_5539200_result.png',
#  '8491200_5768400_result.png',
#  '9066400_5678400_result.png',
#  '9301600_5562400_result.png',
#  '8491600_5774000_result.png',
#  '9055600_5681200_result.png',
#  '8590000_5534000_result.png',
#  '8584000_5539200_result.png',
#  '8289200_5494400_result.png',
#  '8493600_5777600_result.png',
#  '9061200_5678400_result.png',
#  '9065200_5680400_result.png',
#  '8334800_5494400_result.png',
#  '9377200_5529200_result.png',
#  '9374400_5524800_result.png',
#  '8491600_5769200_result.png',
#  '8586800_5536400_result.png',
#  '8495600_5770000_result.png',
#  '9364400_5514000_result.png',
#  '9279200_5873600_result.png',
#  '9286400_5866400_result.png',
#  '9063200_5690000_result.png',
#  '9294000_5564800_result.png',
#  '8826400_5996000_result.png',
#  '8370400_5550400_result.png',
#  '9283200_5677200_result.png',
#  '8492000_5768400_result.png',
#  '9363200_5517600_result.png',
#  '8336000_5491600_result.png',
#  '8490800_5769600_result.png',
#  '8492800_5768400_result.png',
#  '8813200_5995200_result.png',
#  '9068400_5679600_result.png',
#  '9294000_5554000_result.png',
#  '9061200_5679600_result.png',
#  '9268400_5670400_result.png',
#  '9371200_5525600_result.png',
#  '9061600_5690800_result.png',
#  '8336800_5491600_result.png',
#  '9152400_5817200_result.png',
#  '8495600_5765200_result.png',
#  '8334800_5492000_result.png',
#  '9066800_5682000_result.png',
#  '8593200_5530800_result.png',
#  '8336400_5495600_result.png',
#  '9279600_5869600_result.png',
#  '8337600_5493600_result.png',
#  '9063600_5686400_result.png',
#  '9601200_6071600_result.png',
#  '9155200_5818000_result.png',
#  '9150800_5820400_result.png',
#  '9296000_5558800_result.png',
#  '8336400_5490800_result.png',
#  '8291200_5498400_result.png',
#  '8370000_5549200_result.png',
#  '8367200_5550400_result.png',
#  '8865200_5684000_result.png',
#  '8337600_5492800_result.png',
#  '8335200_5490400_result.png',
#  '9154800_5822400_result.png',
#  '9058800_5682000_result.png',
#  '8826800_5995200_result.png',
#  '8368800_5551600_result.png',
#  '9157600_5815200_result.png',
#  '9365600_5528800_result.png',
#  '9063200_5683200_result.png',
#  '8337200_5494800_result.png',
#  '9378400_5528800_result.png',
#  '9275200_5670400_result.png',
#  '9065600_5683200_result.png',
#  '9363600_5526800_result.png',
#  '9063600_5685600_result.png',
#  '9064800_5687600_result.png',
#  '8334800_5496800_result.png',
#  '8589600_5626800_result.png',
#  '8497600_5765200_result.png',
#  '9060400_5689200_result.png',
#  '8289200_5496000_result.png',
#  '9156400_5818400_result.png',
#  '8288400_5496000_result.png',
#  '8491600_5768800_result.png',
#  '9271600_5668800_result.png',
#  '9065200_5682000_result.png',
#  '8584400_5542000_result.png',
#  '8334800_5491600_result.png',
#  '8494800_5777200_result.png',
#  '9067600_5682400_result.png',
#  '9368800_5524400_result.png',
#  '9604800_6077200_result.png',
#  '8586000_5544800_result.png',
#  '9283600_5865200_result.png',
#  '8500000_5772800_result.png',
#  '8492800_5773600_result.png',
#  '9272800_5675600_result.png',
#  '8588400_5535600_result.png',
#  '8366800_5550400_result.png',
#  '9362400_5526800_result.png',
#  '8590400_5632800_result.png',
#  '8490400_5775200_result.png',
#  '8593600_5631200_result.png',
#  '9149200_5822000_result.png',
#  '9152800_5816400_result.png',
#  '9066000_5677200_result.png',
#  '9056400_5683200_result.png',
#  '9156000_5814400_result.png',
#  '9158800_5814400_result.png',
#  '8813600_5990400_result.png',
#  '9293600_5562400_result.png',
#  '8290800_5496000_result.png',
#  '8290000_5496800_result.png',
#  '9364000_5516000_result.png',
#  '8335600_5494000_result.png',
#  '9068800_5683200_result.png',
#  '8824800_5994800_result.png',
#  '8495200_5772800_result.png',
#  '9147600_5818000_result.png',
#  '9368800_5528800_result.png',
#  '9148800_5817600_result.png',
#  '8500800_5765200_result.png',
#  '8817200_5996400_result.png',
#  '8506400_5768400_result.png',
#  '8592800_5535200_result.png',
#  '9067600_5678800_result.png',
#  '8492400_5774400_result.png',
#  '8290000_5499200_result.png',
#  '9277200_5868000_result.png',
#  '8370000_5550400_result.png',
#  '9062000_5682800_result.png',
#  '9287600_5867200_result.png',
#  '9154400_5810400_result.png',
#  '9159200_5816000_result.png',
#  '8491600_5772000_result.png',
#  '8290400_5494000_result.png',
#  '9066400_5684000_result.png',
#  '9280000_5864000_result.png',
#  '8334400_5493200_result.png',
#  '9298000_5553600_result.png',
#  '9062800_5679600_result.png',
#  '9063200_5690400_result.png',
#  '8584000_5541200_result.png',
#  '8335600_5493600_result.png',
#  '8494400_5771600_result.png',
#  '9149600_5814800_result.png',
#  '9062800_5690800_result.png',
#  '9057600_5681600_result.png',
#  '9276400_5675600_result.png',
#  '8493200_5774800_result.png',
#  '9373600_5531200_result.png',
#  '8494000_5776400_result.png',
#  '8290800_5497200_result.png',
#  '9372400_5524400_result.png',
#  '9363600_5524800_result.png',
#  '9277200_5860400_result.png',
#  '9159200_5816800_result.png',
#  '8291600_5496800_result.png',
#  '9069600_5681200_result.png',
#  '8595600_5541600_result.png',
#  '9148800_5815200_result.png',
#  '8336000_5492400_result.png',
#  '9065600_5681200_result.png',
#  '9054000_5681600_result.png',
#  '8488800_5772000_result.png',
#  '8335200_5496400_result.png',
#  '9608000_6072400_result.png',
#  '9066000_5688400_result.png',
#  '8291600_5495600_result.png',
#  '9366000_5523200_result.png',
#  '9056800_5688000_result.png',
#  '9058400_5689600_result.png',
#  '8286800_5498400_result.png',
#  '8504000_5767600_result.png',
#  '9156000_5820000_result.png',
#  '9069200_5683200_result.png',
#  '8369600_5551600_result.png',
#  '8591600_5627600_result.png',
#  '9280800_5862000_result.png',
#  '9069200_5688400_result.png',
#  '8289600_5498800_result.png',
#  '9145600_5819600_result.png',
#  '8864000_5688000_result.png',
#  '8338000_5493600_result.png',
#  '9364400_5517200_result.png',
#  '9160800_5821600_result.png',
#  '8336000_5492000_result.png',
#  '9147600_5818400_result.png',
#  '8821600_5994000_result.png',
#  '8594400_5630800_result.png',
#  '8494400_5774000_result.png',
#  '8333600_5494000_result.png',
#  '9062000_5689200_result.png',
#  '8496000_5775600_result.png',
#  '8494400_5776000_result.png',
#  '9362800_5518400_result.png',
#  '9056000_5682800_result.png',
#  '9062400_5690000_result.png',
#  '8491600_5773200_result.png',
#  '8371200_5550400_result.png',
#  '9302000_5556800_result.png',
#  '8288000_5494800_result.png',
#  '9278000_5674000_result.png',
#  '9153200_5816400_result.png',
#  '9072400_5682400_result.png',
#  '8953200_5840800_result.png',
#  '9378000_5523600_result.png',
#  '9146400_5819600_result.png',
#  '8507600_5772400_result.png',
#  '9267200_5668400_result.png',
#  '9376400_5526800_result.png',
#  '9374000_5524000_result.png',
#  '8369600_5550800_result.png',
#  '9160000_5821600_result.png',
#  '8338400_5492800_result.png',
#  '9362800_5524000_result.png',
#  '9281200_5674000_result.png',
#  '9064400_5684800_result.png',
#  '9268000_5669600_result.png',
#  '8498000_5767200_result.png',
#  '9068400_5680000_result.png',
#  '8590000_5626000_result.png',
#  '9298800_5562800_result.png',
#  '9067600_5682800_result.png',
#  '9605600_6073200_result.png',
#  '8493600_5768800_result.png',
#  '9057600_5688000_result.png',
#  '8495200_5778000_result.png',
#  '9143600_5820000_result.png',
#  '9057600_5686400_result.png',
#  '9066400_5686400_result.png',
#  '8829600_5993200_result.png',
#  '8496800_5774800_result.png',
#  '9362400_5520400_result.png',
#  '8593600_5531200_result.png',
#  '8816000_5990400_result.png',
#  '8494800_5768000_result.png',
#  '9154000_5816800_result.png',
#  '8587200_5535200_result.png',
#  '8583200_5542000_result.png',
#  '9063600_5683600_result.png',
#  '8815600_5995200_result.png',
#  '8814000_5990000_result.png',
#  '9060800_5691600_result.png',
#  '8499200_5772400_result.png',
#  '9062000_5684800_result.png',
#  '8334800_5489600_result.png',
#  '8495200_5776800_result.png',
#  '9266800_5673200_result.png',
#  '8493200_5770000_result.png',
#  '9148400_5820000_result.png',
#  '9070800_5687600_result.png',
#  '9368400_5516400_result.png',
#  '9282000_5873600_result.png',
#  '9363200_5526800_result.png',
#  '9061200_5684800_result.png',
#  '9065600_5687600_result.png',
#  '9068000_5684800_result.png',
#  '9060400_5683600_result.png',
#  '9060000_5690400_result.png',
#  '8494800_5772800_result.png',
#  '8286400_5497200_result.png',
#  '9148000_5814800_result.png',
#  '8492400_5771600_result.png',
#  '9277200_5870400_result.png',
#  '8597200_5538800_result.png',
#  '8820800_5989200_result.png',
#  '9373600_5528000_result.png',
#  '9365600_5521200_result.png',
#  '8495200_5765600_result.png',
#  '8504800_5770800_result.png',
#  '9063200_5682400_result.png',
#  '8493200_5776400_result.png',
#  '8583600_5538400_result.png',
#  '9064000_5679200_result.png',
#  '9061200_5682000_result.png',
#  '8290400_5496400_result.png',
#  '8338000_5494000_result.png',
#  '9604000_6066800_result.png',
#  '9062400_5688800_result.png',
#  '9292800_5558800_result.png',
#  '9148000_5819200_result.png',
#  '9600400_6071600_result.png',
#  '9060000_5689200_result.png',
#  '9284400_5867200_result.png',
#  '8582800_5542400_result.png',
#  '8820800_5990800_result.png',
#  '9276400_5859600_result.png',
#  '9054800_5683600_result.png',
#  '9158400_5819200_result.png',
#  '8335600_5493200_result.png',
#  '9298800_5560400_result.png',
#  '8593200_5626800_result.png',
#  '9144800_5822000_result.png',
#  '9066800_5689200_result.png',
#  '8336800_5493600_result.png',
#  '9374000_5521200_result.png',
#  '9610400_6072000_result.png',
#  '9062800_5679200_result.png',
#  '9061200_5690000_result.png',
#  '9061600_5680000_result.png',
#  '9152400_5822000_result.png',
#  '9066400_5683600_result.png',
#  '9606400_6073200_result.png',
#  '8337600_5493200_result.png',
#  '8333200_5493200_result.png',
#  '9369200_5518000_result.png',
#  '9060400_5681600_result.png',
#  '9068000_5688800_result.png',
#  '9066000_5682400_result.png',
#  '9064000_5688800_result.png',
#  '8336000_5491200_result.png',
#  '9376400_5522000_result.png',
#  '8369200_5550400_result.png',
#  '9150400_5822000_result.png',
#  '9154800_5822000_result.png',
#  '9059200_5690800_result.png',
#  '9057600_5682000_result.png',
#  '8820400_5991200_result.png',
#  '8590800_5530000_result.png',
#  '8286800_5495600_result.png',
#  '9285200_5870800_result.png',
#  '9064000_5687600_result.png',
#  '9362000_5518000_result.png',
#  '9296000_5561600_result.png',
#  '9363600_5514400_result.png',
#  '8338000_5492000_result.png',
#  '9367600_5529600_result.png',
#  '9054400_5681200_result.png',
#  '9362800_5521200_result.png',
#  '9060000_5680800_result.png',
#  '8495200_5767600_result.png',
#  '9060400_5690800_result.png',
#  '9061600_5678000_result.png',
#  '9283200_5868000_result.png',
#  '9059600_5688400_result.png',
#  '8495600_5770800_result.png',
#  '9282400_5872800_result.png',
#  '8498800_5765600_result.png',
#  '9368000_5524000_result.png',
#  '9064800_5685600_result.png',
#  '9152400_5816800_result.png',
#  '9282400_5867600_result.png',
#  '9149600_5816800_result.png',
#  '9154400_5814000_result.png',
#  '9274000_5872800_result.png',
#  '9366400_5522000_result.png',
#  '8495200_5768000_result.png',
#  '9157200_5818000_result.png',
#  '9300400_5559200_result.png',
#  '9368800_5530800_result.png',
#  '9368000_5530000_result.png',
#  '8291600_5499200_result.png',
#  '8594000_5626800_result.png',
#  '9061600_5680400_result.png',
#  '9275600_5864400_result.png',
#  '9151200_5812400_result.png',
#  '8495200_5769600_result.png',
#  '9296800_5561200_result.png',
#  '9280800_5675600_result.png',
#  '9064400_5688400_result.png',
#  '8334400_5494800_result.png',
#  '8495200_5770800_result.png',
#  '8291200_5494800_result.png',
#  '8491200_5769600_result.png',
#  '8334000_5493200_result.png',
#  '9150000_5820400_result.png',
#  '9366400_5515600_result.png',
#  '8334400_5496800_result.png',
#  '8827600_5995200_result.png',
#  '9278800_5872000_result.png',
#  '9372800_5524400_result.png',
#  '9060000_5689600_result.png',
#  '9276000_5664400_result.png',
#  '9266800_5669200_result.png',
#  '9155200_5822400_result.png',
#  '9145600_5815600_result.png',
#  '8291600_5496400_result.png',
#  '8493600_5774400_result.png',
#  '9603600_6073600_result.png',
#  '9065600_5680000_result.png',
#  '8587600_5538800_result.png',
#  '8492400_5774000_result.png',
#  '9267200_5666000_result.png',
#  '8492000_5769200_result.png',
#  '9062000_5690800_result.png',
#  '8493600_5773600_result.png',
#  '9061200_5688000_result.png',
#  '9276400_5664800_result.png',
#  '9602400_6071200_result.png',
#  '9066000_5682000_result.png',
#  '9370800_5528400_result.png',
#  '8866800_5685600_result.png',
#  '8588400_5627600_result.png',
#  '9067200_5685600_result.png',
#  '8508800_5766000_result.png',
#  '9068800_5682800_result.png',
#  '9372000_5522400_result.png',
#  '9362800_5527200_result.png',
#  '9376800_5525200_result.png',
#  '8494800_5771200_result.png',
#  '9068400_5682000_result.png',
#  '9370800_5531200_result.png',
#  '8490800_5776000_result.png',
#  '9064400_5689200_result.png',
#  '9154800_5818400_result.png',
#  '9065200_5684800_result.png',
#  '9280000_5871200_result.png',
#  '9269600_5672400_result.png',
#  '9364000_5527200_result.png',
#  '9055200_5681200_result.png',
#  '8490000_5772000_result.png',
#  '9063200_5679600_result.png',
#  '8368000_5548800_result.png',
#  '9149600_5815600_result.png',
#  '9063600_5682400_result.png',
#  '8337200_5494400_result.png',
#  '8812800_5991600_result.png',
#  '9283200_5867600_result.png',
#  '9150800_5820000_result.png',
#  '8492800_5776800_result.png',
#  '9154800_5816800_result.png',
#  '9368800_5526800_result.png',
#  '8338000_5491200_result.png',
#  '8494400_5772000_result.png',
#  '9064000_5683600_result.png',
#  '8338800_5493200_result.png',
#  '9060800_5688400_result.png',
#  '8864000_5685600_result.png',
#  '8365600_5549200_result.png',
#  '8336400_5491600_result.png',
#  '8828000_5996400_result.png',
#  '8498400_5768400_result.png',
#  '9274000_5668800_result.png',
#  '8491600_5776000_result.png',
#  '9280400_5674400_result.png',
#  '8828000_5995200_result.png',
#  '8289600_5494800_result.png',
#  '8494800_5768800_result.png',
#  '8506800_5771200_result.png',
#  '9054800_5681200_result.png',
#  '8864400_5686400_result.png',
#  '8494800_5779200_result.png',
#  '9062800_5684800_result.png',
#  '8588000_5537600_result.png',
#  '9156800_5820000_result.png',
#  '9066400_5680400_result.png',
#  '9062400_5689200_result.png',
#  '9601200_6069200_result.png',
#  '9061600_5681200_result.png',
#  '9158800_5812800_result.png',
#  '9070400_5690000_result.png',
#  '8493200_5774400_result.png',
#  '9144000_5818000_result.png',
#  '9059600_5690000_result.png',
#  '9364400_5519600_result.png',
#  '9291600_5556800_result.png',
#  '8494400_5776800_result.png',
#  '8368400_5548000_result.png',
#  '8336800_5492000_result.png',
#  '9066000_5686400_result.png',
#  '8495600_5766000_result.png',
#  '9062800_5688000_result.png',
#  '9062400_5690400_result.png',
#  '8367200_5548400_result.png',
#  '8338400_5493200_result.png',
#  '8501600_5772000_result.png',
#  '9295600_5554000_result.png',
#  '8493600_5767200_result.png',
#  '8370400_5550800_result.png',
#  '9373600_5526400_result.png',
#  '9054000_5685600_result.png',
#  '9061600_5680800_result.png',
#  ...]

# %%
_,axs = plt.subplots(1,3, figsize=(20,12))
img.show(ax=axs[0], title='no mask')
img.show(ax=axs[1], y=mask, title='masked')
mask.show(ax=axs[2], title='mask only', alpha=1.)

# %%
onlytifs = [f for f in os.listdir(path_infer) if os.path.isfile(os.path.join(path_infer, f))]
tifs = []
for idx, line in enumerate(onlytifs):
    tifs.append(line.replace('_result.png', '.tif'))
    
for idx, im in enumerate(il):
    msk = learn.predict(im)[0]
    msk.save(path_infer_mask+tifs[idx])

# %%
masktest  = np.array(Image.open(path_infer_mask+tifs[0]))
masktest.sum()`
# Out:
# 14509

# %%
img = il[0]
mask = Image.open(path_infer_mask+tifs[0])

# %%
mask.show()

# %%
type(il[idx])
# Out:
# fastai.vision.image.Image

# %%
il[idx]
# Out:
# Image (3, 400, 400)

# %%
idx = 3

img = np.swapaxes(np.asarray(il[idx].data), 2, 0)

oldpath = path_lbl+tifs[idx]
fixedpath = oldpath.replace(".tif", "_mask.tif")
oldmask = Image.open(fixedpath)

mask = Image.open(path_infer_mask+tifs[idx])

f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True)
ax1.imshow(oldmask)
ax2.imshow(mask)
ax3.imshow(img)
