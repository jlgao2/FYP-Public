# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
path = os.getcwd()

# %%
df = pd.read_csv(path+"/Training_log.csv")

# %%
df
# Out:
#       Step   l_g_gan   l_g_pix  l_g_percep      l_d_real      l_d_fake  \
# 0      100  0.027038  0.001146    1.517000  4.940890e-02  2.488652e-02
# 1      200  0.049789  0.001146    1.448331  5.050000e-05  1.290280e-04
# 2      300  0.023134  0.001127    1.555209  1.398515e-02  1.120752e-02
# 3      400  0.028240  0.001228    1.544191  4.001384e-02  1.255367e-01
# 4      500  0.048399  0.001115    1.564670  1.324920e-04  2.959380e-04
# ..     ...       ...       ...         ...           ...           ...
# 381  38200  0.024538  0.001116    1.434444  3.911117e-03  3.937512e-03
# 382  38300  0.074009  0.001042    1.297521  1.940000e-07  2.050000e-07
# 383  38400  0.051374  0.001109    1.461310  1.880000e-05  1.850000e-05
# 384  38500  0.044820  0.000999    1.500534  7.120000e-05  6.690000e-05
# 385  38600  0.046361  0.000868    1.358802  5.250000e-05  4.880000e-05
#
#      out_d_fake  out_d_real  Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11
# ...

# %%
df["l_g_gan"].plot(title= "l_g_gan", figsize=(8,5))
# Out:
# <AxesSubplot:>

# %%
df = df.set_index('Step').drop(["Unnamed: 8","Unnamed: 9","Unnamed: 10","Unnamed: 11"], axis = 1)

# %%
df
# Out:
#         l_g_gan   l_g_pix  l_g_percep      l_d_real      l_d_fake  out_d_fake  \
# Step
# 100    0.027038  0.001146    1.517000  4.940890e-02  2.488652e-02  -10.325469
# 200    0.049789  0.001146    1.448331  5.050000e-05  1.290280e-04  -10.333913
# 300    0.023134  0.001127    1.555209  1.398515e-02  1.120752e-02  -15.329700
# 400    0.028240  0.001228    1.544191  4.001384e-02  1.255367e-01    3.665192
# 500    0.048399  0.001115    1.564670  1.324920e-04  2.959380e-04   -9.435129
# ...         ...       ...         ...           ...           ...         ...
# 38200  0.024538  0.001116    1.434444  3.911117e-03  3.937512e-03   35.379520
# 38300  0.074009  0.001042    1.297521  1.940000e-07  2.050000e-07   27.963156
# 38400  0.051374  0.001109    1.461310  1.880000e-05  1.850000e-05   29.576014
# 38500  0.044820  0.000999    1.500534  7.120000e-05  6.690000e-05   37.379196
# 38600  0.046361  0.000868    1.358802  5.250000e-05  4.880000e-05   -2.760093
#
#        out_d_real
# Step
# ...

# %%
plt.figure(figsize=(16,20))
i = 0
for series in df:    
    plt.subplot(4,2,i+1)
    df[series].plot(title= series, sharex = True)
    i += 1
